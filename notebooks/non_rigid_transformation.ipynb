# %% [markdown]
# ### This notebook includes non-rigid tranformations using Affine and B-Spline

# %%
# Import Libraries
import os
from pathlib import Path
import numpy as np
import pandas as pd
import SimpleITK as sitk
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
from utils_c import *

# %%
# get the current working directory
cwd = os.getcwd()
print(cwd)
# go over the data directory
data_dir = Path(cwd).parent / 'data' / 'nifti' 
print(data_dir)
# Out:
# d:\VS_Projects\MIRA_FINAL_PROJECT\notebooks
# d:\VS_Projects\MIRA_FINAL_PROJECT\data\nifti

# %%
img_f, landmark_f = get_data_paths(p="e", i=1)
img_m, landmark_m = get_data_paths(p="i", i=1)

# %%
# apply affine transformation
# !elastix -f {img_f} -m {img_m} -p ../data/param_affine.txt -out ../data/affine
# Out:
# elastix is started at Mon Dec  5 23:46:01 2022.
#
# which elastix:   elastix
# elastix runs at: DESKTOP-UP0FCMD
#   Windows  Professional (x64),  (Build 9200)
#   with 16258 MB memory, and 2 cores @ 2904 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "../data/param_affine.txt".
#
# Current time: Mon Dec  5 23:46:01 2022.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        ../data/nifti/copd1_eBHCT.nii.gz
# -m        ../data/nifti/copd1_iBHCT.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      ..\data\affine\
# -p        ../data/param_affine.txt
# -priority unspecified, so NORMAL process priority
# -threads  unspecified, so all available threads are used
# Command line options from TransformBase:
# ...
